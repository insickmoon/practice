# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 실제 영업점 데이터 정제하기

# %%
# 1. 현금매출정보 정리하기
cash_df = pd.read_csv("./실제 영업점 매출 데이터/현금매출정보.csv", encoding='utf8')

# %%
cash_df.head()
# Out:
#   거래유형     거래종류 K/S                  사용자정보       금액  봉사료      세금         승인번호  \
# 0   승인  사업자지출증빙   K          010-****-3337   33,000    0   2,997  122866901.0
# 1   승인  소비자소득공제   K          010-****-8265   18,000    0   1,636  122843518.0
# 2   승인  사업자지출증빙   S  1544-2020-****-972922  108,000    0   9,813  122875332.0
# 3   승인  사업자지출증빙   K           11*-**-*3664  184,000    0  16,720  121137601.0
# 4   승인  사업자지출증빙   K           10*-**-*0667   88,000    0   7,992  121132584.0
#
#            상호       사업자번호     단말기번호        제품번호               거래일시  거절사유 취소유형  \
# 0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-30 18:19:31  정상완료  NaN
# 1  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-25 23:21:55  정상완료  NaN
# 2  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-15 19:54:36  정상완료  NaN
# 3  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-13 20:11:39  정상완료  NaN
# 4  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-04 20:42:03  정상완료  NaN
#
#   원거래일시  원거래승인번호
# ...

# %%
cash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   거래유형     234 non-null    object
#  1   거래종류     234 non-null    object
#  2   K/S      234 non-null    object
#  3   사용자정보    234 non-null    object
#  4   금액       234 non-null    object
#  5   봉사료      234 non-null    int64
#  6   세금       234 non-null    object
#  7   승인번호     226 non-null    float64
#  8   상호       234 non-null    object
#  9   사업자번호    234 non-null    int64
#  10  단말기번호    234 non-null    int64
#  11  제품번호     234 non-null    int64
#  12  거래일시     234 non-null    object
#  13  거절사유     234 non-null    object
#  14  취소유형     12 non-null     object
#  15  원거래일시    8 non-null      object
#  16  원거래승인번호  7 non-null      float64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 31.2+ KB

# %%
# 2. 카드매출정보 정리하기
credit_df = pd.read_csv('./실제 영업점 매출 데이터/카드매출정보.csv', encoding='utf8')

# %%
credit_df.head()
# Out:
#    거래구분 취소유형     단말기번호          발급사  매입사 매입방식                거래일시 체크  \
# 0    승인       12728749   광주           비씨  NaN   18/01/02 20:53:47
# 1    승인       12728749   삼성           삼성  NaN   18/01/02 20:59:42
# 2    승인       12728749   삼성           삼성  NaN   18/01/02 21:00:48
# 3    승인       12728749   신한           신한  NaN   18/01/02 21:06:26
# 4    승인       12728749   농협           농협  NaN   18/01/02 21:37:16
#
#                    카드번호   할부기간      승인번호            금액      봉사료           세금
# 0   4599-52**-****-2072    0.0  71288818   132000(KRW)   0(KRW)   11989(KRW)
# 1   4009-07**-****-7087    0.0  39611435    56000(KRW)   0(KRW)    5084(KRW)
# 2   4009-13**-****-0782    0.0  57213771    42000(KRW)   0(KRW)    3815(KRW)
# 3   5525-76**-****-4376    0.0  32901496    93000(KRW)   0(KRW)    8449(KRW)
# 4   4092-16**-****-5617    0.0  30000702    66000(KRW)   0(KRW)    5995(KRW)

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19430 entries, 0 to 19429
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0    거래구분   19430 non-null  object
#  1   취소유형    14704 non-null  object
#  2   단말기번호   19430 non-null  int64
#  3   발급사     19430 non-null  object
#  4   매입사     19430 non-null  object
#  5   매입방식    4792 non-null   object
#  6   거래일시    19430 non-null  object
#  7   체크      15920 non-null  object
#  8   카드번호    19430 non-null  object
#  9    할부기간   14656 non-null  float64
#  10  승인번호    19393 non-null  object
#  11  금액      19430 non-null  object
#  12  봉사료     19430 non-null  object
#  13  세금      19430 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %% [markdown]
# # 3. 현금매출 정보 중 거래 유형 확인하여 실제 승인된 건만 정리하기

# %%
# 3. 현금매출 정보 중 거래 유형 확인하여 실제 승인된 건만 정리하기 
cash_df.거래유형.value_counts()
# Out:
# 승인      218
# 거절        8
# 취소        4
# 취소실패      4
# Name: 거래유형, dtype: int64

# %%
cash_df[cash_df.거래유형=="거절"]
# Out:
#     거래유형     거래종류 K/S         사용자정보       금액  봉사료      세금  승인번호          상호  \
# 84    거절  소비자소득공제   K    00888-****   50,000    0   4,542   NaN  강너머남촌숯불닭갈비
# 98    거절  소비자소득공제   K    01063-****   61,000    0   5,541   NaN  강너머남촌숯불닭갈비
# 141   거절  소비자소득공제   K    01088-****   37,000    0   3,361   NaN  강너머남촌숯불닭갈비
# 142   거절  소비자소득공제   K    01088-****   37,000    0   3,361   NaN  강너머남촌숯불닭갈비
# 152   거절  소비자소득공제   K    01088-****   24,000    0   2,180   NaN  강너머남촌숯불닭갈비
# 168   거절  소비자소득공제   K    01088-****   44,000    0   3,996   NaN  강너머남촌숯불닭갈비
# 184   거절  소비자소득공제   K  11*-**-*6516  139,000    0  12,630   NaN  강너머남촌숯불닭갈비
# 222   거절  소비자소득공제   K            00   76,000    0   6,901   NaN  강너머남촌숯불닭갈비
#
#           사업자번호     단말기번호        제품번호               거래일시                 거절사유  \
# 84   2364100335  12728749  8070501001  19-02-11 22:09:17  신분번호오류    (10-13자리)
# 98   2364100335  12728749  8070501001  19-06-05 19:03:55  신분번호오류    (10-13자리)
# ...

# %%
cash_df.iloc[80:90,:]
# Out:
#    거래유형     거래종류 K/S          사용자정보       금액  봉사료      세금         승인번호  \
# 80   승인  소비자소득공제   K  010-****-0911   89,000    0   8,083  122897399.0
# 81   승인  소비자소득공제   K  010-****-6409  147,000    0  13,351  121092726.0
# 82   승인  소비자소득공제   K  010-****-3104   93,000    0   8,447  122881874.0
# 83   승인  소비자소득공제   K  010-****-7452   62,000    0   5,632  121120892.0
# 84   거절  소비자소득공제   K     00888-****   50,000    0   4,542          NaN
# 85   승인  소비자소득공제   K  010-****-8208   50,000    0   4,540  121108805.0
# 86   승인  소비자소득공제   K  010-****-0796   64,000    0   5,811  121122840.0
# 87   승인  소비자소득공제   K  010-****-1712   60,000    0   5,450  122869052.0
# 88   승인  소비자소득공제   K  010-****-6712   24,000    0   2,180  122908259.0
# 89   승인  소비자소득공제   K  010-****-8864   64,000    0   5,812  121096133.0
#
#             상호       사업자번호     단말기번호        제품번호               거래일시  \
# 80  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-10-02 20:38:05
# ...

# %%
cash_df.iloc[95:105,:]
# Out:
#     거래유형     거래종류 K/S                  사용자정보       금액  봉사료      세금  \
# 95    승인  소비자소득공제   K          010-****-8523   48,000    0   4,361
# 96    승인  소비자소득공제   S  1544-2020-****-878045   81,000    0   7,360
# 97    승인  소비자소득공제   K          010-****-0420   92,000    0   8,357
# 98    거절  소비자소득공제   K             01063-****   61,000    0   5,541
# 99    승인  소비자소득공제   K          010-****-3158   36,000    0   3,269
# 100   승인  소비자소득공제   K          010-****-1759  584,000    0  53,058
# 101   승인  소비자소득공제   K          010-****-7158   43,000    0   3,906
# 102   승인  소비자소득공제   K          010-****-9600   20,000    0   1,817
# 103   승인  소비자소득공제   K          010-****-9600   37,000    0   3,360
# 104   승인  소비자소득공제   K          010-****-7599   41,000    0   3,724
#
#             승인번호          상호       사업자번호     단말기번호        제품번호  \
# 95   121077581.0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001
# 96   122875147.0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001
# ...

# %%
cash_df.iloc[135:145,:]
# Out:
#     거래유형     거래종류 K/S                  사용자정보      금액  봉사료     세금         승인번호  \
# 135   승인  소비자소득공제   K          010-****-9844  50,000    0  4,544  121055036.0
# 136   승인  소비자소득공제   K          010-****-1516  33,000    0  2,998  121054606.0
# 137   승인  사업자지출증빙   S  1544-2020-****-774944  39,000    0  3,542  122949596.0
# 138   승인  소비자소득공제   K          010-****-3822  56,000    0  5,087  121046360.0
# 139   승인  소비자소득공제   K          010-****-3822  61,000    0  5,542  121046593.0
# 140   승인  소비자소득공제   K          010-****-1712  37,000    0  3,361  122938363.0
# 141   거절  소비자소득공제   K             01088-****  37,000    0  3,361          NaN
# 142   거절  소비자소득공제   K             01088-****  37,000    0  3,361          NaN
# 143   승인  소비자소득공제   K          010-****-9639  50,000    0  4,541  121036215.0
# 144   승인  소비자소득공제   K          010-****-8175  63,000    0  5,723  121043015.0
#
#              상호       사업자번호     단말기번호        제품번호               거래일시  \
# ...

# %%
cash_df[cash_df.거래유형=="취소실패"]
# Out:
#     거래유형     거래종류 K/S          사용자정보      금액  봉사료 세금         승인번호          상호  \
# 60  취소실패  소비자소득공제   K  010-****-1712  51,000    0  0  121122036.0  강너머남촌숯불닭갈비
# 61  취소실패  소비자소득공제   K  010-****-1712  51,000    0  0  121122036.0  강너머남촌숯불닭갈비
# 62  취소실패  소비자소득공제   K  010-****-1712  51,000    0  0  121122036.0  강너머남촌숯불닭갈비
# 63  취소실패  소비자소득공제   K      0108-****  51,000    0  0  121122036.0  강너머남촌숯불닭갈비
#
#          사업자번호     단말기번호        제품번호               거래일시                 거절사유  \
# 60  2364100335  12728749  8070501001  18-11-26 21:18:56                원거래없음
# 61  2364100335  12728749  8070501001  18-11-26 21:18:24                원거래없음
# 62  2364100335  12728749  8070501001  18-11-26 21:17:59                원거래없음
# 63  2364100335  12728749  8070501001  18-11-26 21:17:31  신분번호오류    (10-13자리)
#
#        취소유형     원거래일시      원거래승인번호
# 60  단말기일반취소  18-11-26  121122036.0
# 61  단말기일반취소  18-11-26  121122036.0
# 62  단말기일반취소  18-11-26  121122036.0
# 63  단말기일반취소  18-11-26          NaN

# %%
cash_df.iloc[55:65,:]
# Out:
#     거래유형     거래종류 K/S                  사용자정보      금액  봉사료     세금         승인번호  \
# 55    승인  소비자소득공제   K          010-****-1712  24,000    0  2,180  121090931.0
# 56    승인  소비자소득공제   K          010-****-1791  43,000    0  3,905  122897723.0
# 57    승인  소비자소득공제   K          010-****-5142  42,000    0  3,816  122909750.0
# 58    승인  소비자소득공제   K          010-****-8490  52,000    0  4,724  121091757.0
# 59    승인  사업자지출증빙   S  1544-2020-****-289423  44,000    0  3,996  121092700.0
# 60  취소실패  소비자소득공제   K          010-****-1712  51,000    0      0  121122036.0
# 61  취소실패  소비자소득공제   K          010-****-1712  51,000    0      0  121122036.0
# 62  취소실패  소비자소득공제   K          010-****-1712  51,000    0      0  121122036.0
# 63  취소실패  소비자소득공제   K              0108-****  51,000    0      0  121122036.0
# 64    승인  소비자소득공제   K          010-****-5712  51,000    0  4,633  121122036.0
#
#             상호       사업자번호     단말기번호        제품번호               거래일시  \
# ...

# %%
cash_df[cash_df.거래유형=="취소"]
# Out:
#     거래유형     거래종류 K/S          사용자정보       금액  봉사료      세금         승인번호  \
# 21    취소  사업자지출증빙   K  010-****-2854   92,000    0   8,357  121147697.0
# 70    취소  소비자소득공제   K  010-****-1664   94,000    0   8,541  122902653.0
# 74    취소  소비자소득공제   K  010-****-0895  268,000    0  24,352  121118612.0
# 180   취소  소비자소득공제   K  010-****-7734   48,000    0   4,360  121084630.0
#
#              상호       사업자번호     단말기번호        제품번호               거래일시  거절사유  \
# 21   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-05-07 20:35:26  정상완료
# 70   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-10-26 19:43:17  정상완료
# 74   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-10-20 21:00:24  정상완료
# 180  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  19-11-21 20:12:07  정상완료
#
#         취소유형     원거래일시      원거래승인번호
# 21   단말기일반취소  18-05-07  121147338.0
# 70   단말기일반취소  18-10-26  121097056.0
# 74   단말기일반취소  18-10-20  121118521.0
# 180  단말기일반취소  19-11-21  121084579.0

# %%
cash_df.iloc[20:30,:]
# Out:
#    거래유형     거래종류 K/S                  사용자정보       금액  봉사료      세금  \
# 20   승인  사업자지출증빙   K          010-****-2854   92,000    0   8,357
# 21   취소  사업자지출증빙   K          010-****-2854   92,000    0   8,357
# 22   승인  사업자지출증빙   K          010-****-2854   92,000    0   8,357
# 23   승인  사업자지출증빙   K           10*-**-*6725  140,000    0  12,717
# 24   승인  소비자소득공제   K          010-****-3998   54,000    0   4,905
# 25   승인  사업자지출증빙   S  1544-2020-****-368538  207,000    0  18,805
# 26   승인  사업자지출증빙   K           10*-**-*6725  125,000    0  11,363
# 27   승인  소비자소득공제   K          010-****-6364   57,000    0   5,174
# 28   승인  소비자소득공제   K          010-****-8265   43,000    0   3,908
# 29   승인  소비자소득공제   K          010-****-3275  212,000    0  19,267
#
#            승인번호          상호       사업자번호     단말기번호        제품번호  \
# 20  122850447.0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001
# 21  121147697.0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001
# ...

# %%
cash_df.iloc[65:75,:]
# Out:
#    거래유형     거래종류 K/S          사용자정보       금액  봉사료      세금         승인번호  \
# 65   승인  사업자지출증빙   K   21*-**-*0111   43,000    0   3,906  121107069.0
# 66   승인  소비자소득공제   K  010-****-5474   44,000    0   3,996  121100565.0
# 67   승인  소비자소득공제   K  010-****-2079   24,000    0   2,180  121107661.0
# 68   승인  소비자소득공제   K  010-****-1637  104,000    0   9,452  121103715.0
# 69   승인  소비자소득공제   K  010-****-1664   82,000    0   7,450  122902594.0
# 70   취소  소비자소득공제   K  010-****-1664   94,000    0   8,541  122902653.0
# 71   승인  소비자소득공제   K  010-****-1664   94,000    0   8,541  121097056.0
# 72   승인  소비자소득공제   K  010-****-2370   57,000    0   5,179  122907001.0
# 73   승인  소비자소득공제   K  010-****-8959  268,000    0  24,352  121118662.0
# 74   취소  소비자소득공제   K  010-****-0895  268,000    0  24,352  121118612.0
#
#             상호       사업자번호     단말기번호        제품번호               거래일시  거절사유  \
# 65  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-11-26 18:57:21  정상완료
# ...

# %% [markdown]
# # 거래 유형을 확인한 뒤에
# # 거절, 취소실패는 그냥 삭제하면 되는데, 취소는 그냥 삭제하면 안됨.
# # 원거래 부분을 찾아내서 그것도 같이 삭제해줘야지 데이터가 중복되지 않음
# # 취소 전표를 처리할 때는
# # 1. 취소 전표의 '원거래승인번호' 칼럼에 저장되어있는 승인번호를 확인
# # 2. 동일한 승인번호를 가진 승인 전표를 찾아냄
# # 3. 해당 승인 전표와 취소 전표를 모두 삭제

# %% [markdown]
# # 여기서부터 현금데이터의 거래 유형 정리하는 파트

# %%
# 3-1. 취소 전표 처리 후 승인 전표만 모으기

# %%
cash_canceled = cash_df[cash_df.거래유형 =='취소']['원거래승인번호']

# %%
cash_df[cash_df.승인번호.isin(cash_canceled)]
# Out:
#     거래유형     거래종류 K/S          사용자정보       금액  봉사료      세금         승인번호  \
# 22    승인  사업자지출증빙   K  010-****-2854   92,000    0   8,357  121147338.0
# 71    승인  소비자소득공제   K  010-****-1664   94,000    0   8,541  121097056.0
# 75    승인  소비자소득공제   K  010-****-0895  268,000    0  24,352  121118521.0
# 181   승인  소비자소득공제   K  010-****-7734   48,000    0   4,360  121084579.0
#
#              상호       사업자번호     단말기번호        제품번호               거래일시  거절사유  \
# 22   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-05-07 20:32:35  정상완료
# 71   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-10-26 19:41:53  정상완료
# 75   강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-10-20 20:59:37  정상완료
# 181  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  19-11-21 20:11:30  정상완료
#
#         취소유형 원거래일시  원거래승인번호
# 22   단말기일반취소   NaN      NaN
# 71   단말기일반취소   NaN      NaN
# 75   단말기일반취소   NaN      NaN
# 181  단말기일반취소   NaN      NaN

# %%
cash_df = cash_df[~cash_df.승인번호.isin(cash_canceled)]

# %%
cash_df = cash_df[cash_df.거래유형 =="승인"]

# %%
cash_df.reset_index(drop=True, inplace=True)

# %%
cash_df.거래유형.value_counts()
# Out:
# 승인    214
# Name: 거래유형, dtype: int64

# %% [markdown]
# # 4. 카드매출 정보 중 거래 유형 확인하여 실제 승인된 건만 정리하기

# %%
credit_df.head()
# Out:
#    거래구분 취소유형     단말기번호          발급사  매입사 매입방식                거래일시 체크  \
# 0    승인       12728749   광주           비씨  NaN   18/01/02 20:53:47
# 1    승인       12728749   삼성           삼성  NaN   18/01/02 20:59:42
# 2    승인       12728749   삼성           삼성  NaN   18/01/02 21:00:48
# 3    승인       12728749   신한           신한  NaN   18/01/02 21:06:26
# 4    승인       12728749   농협           농협  NaN   18/01/02 21:37:16
#
#                    카드번호   할부기간      승인번호            금액      봉사료           세금
# 0   4599-52**-****-2072    0.0  71288818   132000(KRW)   0(KRW)   11989(KRW)
# 1   4009-07**-****-7087    0.0  39611435    56000(KRW)   0(KRW)    5084(KRW)
# 2   4009-13**-****-0782    0.0  57213771    42000(KRW)   0(KRW)    3815(KRW)
# 3   5525-76**-****-4376    0.0  32901496    93000(KRW)   0(KRW)    8449(KRW)
# 4   4092-16**-****-5617    0.0  30000702    66000(KRW)   0(KRW)    5995(KRW)

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19430 entries, 0 to 19429
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0    거래구분   19430 non-null  object
#  1   취소유형    14704 non-null  object
#  2   단말기번호   19430 non-null  int64
#  3   발급사     19430 non-null  object
#  4   매입사     19430 non-null  object
#  5   매입방식    4792 non-null   object
#  6   거래일시    19430 non-null  object
#  7   체크      15920 non-null  object
#  8   카드번호    19430 non-null  object
#  9    할부기간   14656 non-null  float64
#  10  승인번호    19393 non-null  object
#  11  금액      19430 non-null  object
#  12  봉사료     19430 non-null  object
#  13  세금      19430 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
credit_df.columns = credit_df.columns.str.replace(" ","")

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19430 entries, 0 to 19429
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래구분    19430 non-null  object
#  1   취소유형    14704 non-null  object
#  2   단말기번호   19430 non-null  int64
#  3   발급사     19430 non-null  object
#  4   매입사     19430 non-null  object
#  5   매입방식    4792 non-null   object
#  6   거래일시    19430 non-null  object
#  7   체크      15920 non-null  object
#  8   카드번호    19430 non-null  object
#  9   할부기간    14656 non-null  float64
#  10  승인번호    19393 non-null  object
#  11  금액      19430 non-null  object
#  12  봉사료     19430 non-null  object
#  13  세금      19430 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
credit_df.거래구분.value_counts()
# Out:
#  승인      14376
# 승인        4715
#  거절        155
#  취소        106
# 거절          42
# 취소          31
# 취소실패         4
#  취소실패        1
# Name: 거래구분, dtype: int64

# %%
credit_df.거래구분 = credit_df.거래구분.str.replace(" ","")

# %%
credit_df.거래구분.value_counts()
# Out:
# 승인      19091
# 거절        197
# 취소        137
# 취소실패        5
# Name: 거래구분, dtype: int64

# %%
credit_df[credit_df.거래구분 =="거절"]
# Out:
#       거래구분 취소유형     단말기번호          발급사  매입사 매입방식                거래일시   체크  \
# 174     거절       12728749   삼성           삼성  NaN   18/01/13 20:26:23
# 276     거절       12728749   비씨           비씨  NaN   18/01/19 23:28:52    Y
# 277     거절       12728749   비씨           비씨  NaN   18/01/19 23:29:22    Y
# 278     거절       12728749   비씨           비씨  NaN   18/01/19 23:30:12    Y
# 283     거절       12728749   신한           신한  NaN   18/01/19 22:31:35
# ...    ...  ...       ...          ...  ...  ...                 ...  ...
# 18970   거절  NaN  12728749           농협   농협  DSC   20-11-10 19:53:31  NaN
# 19059   거절  NaN  12728749           외환   외환  DSC   20-11-14 19:30:15    Y
# 19060   거절  NaN  12728749           외환   외환  DSC   20-11-14 19:30:40    Y
# 19255   거절  NaN  12728749           비씨   비씨  DSC   20-11-26 19:49:02  NaN
# 19267   거절  NaN  12728749           비씨   비씨  DSC   20-11-27 19:13:10  NaN
#
#                        카드번호  할부기간      승인번호            금액      봉사료  \
# ...

# %%
credit_df.iloc[170:180,:]
# Out:
#     거래구분 취소유형     단말기번호          발급사    매입사 매입방식                거래일시  체크  \
# 170   승인       12728749   비씨             비씨  NaN   18/01/13 20:09:46
# 171   승인       12728749   KB국민         KB국민  NaN   18/01/13 18:06:22   Y
# 172   승인       12728749   신한             신한  NaN   18/01/13 20:10:35   Y
# 173   승인       12728749   삼성             삼성  NaN   18/01/13 20:21:01
# 174   거절       12728749   삼성             삼성  NaN   18/01/13 20:26:23
# 175   승인       12728749   비씨             비씨  NaN   18/01/13 20:27:13
# 176   승인       12728749   삼성             삼성  NaN   18/01/13 20:40:59
# 177   승인       12728749   비씨             비씨  NaN   18/01/14 20:58:47   Y
# 178   승인       12728749   하나             외환  NaN   18/01/14 21:04:33
# 179   승인       12728749   현대             현대  NaN   18/01/14 18:43:56
#
#                      카드번호  할부기간      승인번호            금액      봉사료           세금
# 170   4140-32**-****-5937   0.0  79921685    64000(KRW)   0(KRW)    5813(KRW)
# ...

# %%
credit_df.iloc[270:280,:]
# Out:
#     거래구분 취소유형     단말기번호          발급사    매입사 매입방식                거래일시  체크  \
# 270   승인       12728749   비씨             비씨  NaN   18/01/18 20:13:40
# 271   승인       12728749   신한             신한  NaN   18/01/18 22:08:14
# 272   승인       12728749   하나             외환  NaN   18/01/19 20:00:23
# 273   승인       12728749   농협             농협  NaN   18/01/19 20:36:08
# 274   승인       12728749   KB국민         KB국민  NaN   18/01/19 21:18:09   Y
# 275   승인       12728749   비씨             비씨  NaN   18/01/19 22:06:33
# 276   거절       12728749   비씨             비씨  NaN   18/01/19 23:28:52   Y
# 277   거절       12728749   비씨             비씨  NaN   18/01/19 23:29:22   Y
# 278   거절       12728749   비씨             비씨  NaN   18/01/19 23:30:12   Y
# 279   승인       12728749   비씨             비씨  NaN   18/01/19 23:38:08
#
#                      카드번호  할부기간      승인번호           금액      봉사료          세금
# 270   6541-15**-****-1736   0.0  70174775   57000(KRW)   0(KRW)   5176(KRW)
# ...

# %%
credit_df[credit_df.거래구분 =="취소"]
# Out:
#       거래구분        취소유형     단말기번호          발급사    매입사 매입방식                거래일시  \
# 30      취소   CAT 취소(0)  12728749   KB국민         KB국민  NaN   18/01/03 17:48:00
# 34      취소   CAT 취소(0)  12728749   신협             비씨  NaN   18/01/04 18:23:27
# 69      취소   CAT 취소(0)  12728749   신한             신한  NaN   18/01/05 21:50:54
# 260     취소   CAT 취소(0)  12728749   비씨             비씨  NaN   18/01/18 21:16:47
# 294     취소   CAT 취소(0)  12728749   비씨             비씨  NaN   18/01/19 20:28:43
# ...    ...         ...       ...          ...    ...  ...                 ...
# 18705   취소   CAT 취소(0)  12728749           신한     신한  DSC   20-10-27 18:30:15
# 19010   취소   CAT 취소(0)  12728749           비씨     비씨  DSC   20-11-12 18:47:07
# 19011   취소   CAT 취소(0)  12728749           비씨     비씨  DSC   20-11-12 18:47:21
# 19148   취소   CAT 취소(0)  12728749           비씨     비씨  DSC   20-11-18 22:25:22
# 19172   취소   CAT 취소(0)  12728749           신한     신한  DSC   20-11-19 22:43:45
#
# ...

# %%
credit_df.iloc[25:40,:]
# Out:
#    거래구분        취소유형     단말기번호          발급사    매입사 매입방식                거래일시  \
# 25   승인              12728749   하나             외환  NaN   18/01/03 23:21:18
# 26   승인              12728749   비씨             비씨  NaN   18/01/03 19:42:08
# 27   승인              12728749   KB국민         KB국민  NaN   18/01/03 19:43:34
# 28   승인              12728749   KB국민         KB국민  NaN   18/01/03 23:57:40
# 29   승인   CAT 취소(0)  12728749   KB국민         KB국민  NaN   18/01/03 17:47:18
# 30   취소   CAT 취소(0)  12728749   KB국민         KB국민  NaN   18/01/03 17:48:00
# 31   승인              12728749   비씨             비씨  NaN   18/01/03 17:48:22
# 32   승인              12728749   삼성             삼성  NaN   18/01/04 20:29:37
# 33   승인   CAT 취소(0)  12728749   신협             비씨  NaN   18/01/04 18:20:15
# 34   취소   CAT 취소(0)  12728749   신협             비씨  NaN   18/01/04 18:23:27
# 35   승인              12728749   신협             비씨  NaN   18/01/04 18:25:29
# ...

# %%
credit_df[credit_df.거래구분=="취소실패"]
# Out:
#        거래구분        취소유형     단말기번호          발급사  매입사 매입방식                거래일시  \
# 4799   취소실패   CAT 취소(0)  12728749   신협           비씨  NaN   18/10/09 20:55:47
# 16042  취소실패   CAT 취소(0)  12728749           현대   현대  DSC   20-05-21 21:47:45
# 16043  취소실패   CAT 취소(0)  12728749           현대   현대  DSC   20-05-21 21:48:00
# 16044  취소실패   CAT 취소(0)  12728749           현대   현대  DSC   20-05-21 21:48:59
# 16045  취소실패   CAT 취소(0)  12728749           현대   현대  DSC   20-05-21 21:49:32
#
#         체크                  카드번호  할부기간      승인번호            금액      봉사료  \
# 4799     Y   9490-49**-****-1316   0.0  27813685   128000(KRW)   0(KRW)
# 16042  NaN   4028-57**-****-1880   NaN  00477103        92,000        0
# 16043  NaN   4028-57**-****-1880   NaN  00477103        92,000        0
# 16044  NaN   4028-57**-****-1880   NaN  00477103        92,000        0
# 16045  NaN   4028-57**-****-9706   NaN  00477103        92,000        0
#
#             세금
# 4799    0(KRW)
# 16042        0
# 16043        0
# ...

# %%
credit_df.iloc[4795:4805,:]
# Out:
#       거래구분        취소유형     단말기번호          발급사  매입사 매입방식                거래일시  \
# 4795    승인              12728749   농협           농협  NaN   18/10/09 22:58:39
# 4796    승인              12728749   농협           농협  NaN   18/10/09 00:52:08
# 4797    승인   CAT 취소(0)  12728749   신협           비씨  NaN   18/10/09 18:36:06
# 4798    승인              12728749   신협           비씨  NaN   18/10/09 18:36:20
# 4799  취소실패   CAT 취소(0)  12728749   신협           비씨  NaN   18/10/09 20:55:47
# 4800    취소   CAT 취소(0)  12728749   신협           비씨  NaN   18/10/09 20:56:58
# 4801    승인              12728749   신협           비씨  NaN   18/10/09 20:57:26
# 4802    승인              12728749   농협           농협  NaN   18/10/09 21:02:58
# 4803    승인   CAT 취소(0)  12728749   현대           현대  NaN   18/10/09 18:44:56
# 4804    승인              12728749   현대           현대  NaN   18/10/09 16:49:58
#
#       체크                  카드번호  할부기간      승인번호            금액      봉사료  \
# ...

# %%
credit_df.iloc[16040:16050,:]
# Out:
#        거래구분       취소유형     단말기번호   발급사   매입사 매입방식               거래일시   체크  \
# 16040    승인        NaN  12728749    삼성    삼성  DSC  20-05-21 21:10:47  NaN
# 16041    승인        NaN  12728749  KB국민  KB국민  DSC  20-05-21 21:11:08    Y
# 16042  취소실패  CAT 취소(0)  12728749    현대    현대  DSC  20-05-21 21:47:45  NaN
# 16043  취소실패  CAT 취소(0)  12728749    현대    현대  DSC  20-05-21 21:48:00  NaN
# 16044  취소실패  CAT 취소(0)  12728749    현대    현대  DSC  20-05-21 21:48:59  NaN
# 16045  취소실패  CAT 취소(0)  12728749    현대    현대  DSC  20-05-21 21:49:32  NaN
# 16046    승인        NaN  12728749    신한    신한  DSC  20-05-21 21:51:42  NaN
# 16047    승인        NaN  12728749    비씨    비씨  DSC  20-05-21 21:57:17  NaN
# 16048    승인        NaN  12728749  KB국민  KB국민  DSC  20-05-21 22:12:17  NaN
# 16049    승인        NaN  12728749    비씨    비씨  DSC  20-05-21 22:58:29    Y
#
#                       카드번호  할부기간      승인번호       금액 봉사료      세금
# 16040  9410-10**-****-3317   NaN  35432154   58,000   0   5,268
# ...

# %% [markdown]
# # 카드 매출도 현금매출과 동일함.
# # 취소는 동일한 승인번호를 가진 매출데이터를 삭제한 뒤에 취소 전표 제거.
# # 거절과 취소실패 전표는 그냥 삭제.

# %%
# 4-1. 취소 전표 정리하고 거절과 취소실패 삭제하기 
credit_canceled = credit_df[credit_df.거래구분=="취소"]["승인번호"]

# %%
credit_canceled
# Out:
# 30       30065400
# 34       75850370
# 69       10439872
# 260      70708331
# 294      78954845
#            ...
# 18705    43582809
# 19010    75442431
# 19011    75445094
# 19148    75682316
# 19172    03528972
# Name: 승인번호, Length: 137, dtype: object

# %%
credit_df = credit_df[~credit_df.승인번호.isin(credit_canceled)]

# %%
credit_df = credit_df[credit_df.거래구분 == "승인"]

# %%
credit_df.거래구분.value_counts()
# Out:
# 승인    18953
# Name: 거래구분, dtype: int64

# %% [markdown]
# # 5. 현금과 카드 데이터 하나로 합치기

# %%
cash_df.head()
# Out:
#   거래유형     거래종류 K/S                  사용자정보       금액  봉사료      세금         승인번호  \
# 0   승인  사업자지출증빙   K          010-****-3337   33,000    0   2,997  122866901.0
# 1   승인  소비자소득공제   K          010-****-8265   18,000    0   1,636  122843518.0
# 2   승인  사업자지출증빙   S  1544-2020-****-972922  108,000    0   9,813  122875332.0
# 3   승인  사업자지출증빙   K           11*-**-*3664  184,000    0  16,720  121137601.0
# 4   승인  사업자지출증빙   K           10*-**-*0667   88,000    0   7,992  121132584.0
#
#            상호       사업자번호     단말기번호        제품번호               거래일시  거절사유 취소유형  \
# 0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-30 18:19:31  정상완료  NaN
# 1  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-25 23:21:55  정상완료  NaN
# 2  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-15 19:54:36  정상완료  NaN
# 3  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-13 20:11:39  정상완료  NaN
# 4  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-04 20:42:03  정상완료  NaN
#
#   원거래일시  원거래승인번호
# ...

# %%
credit_df.head()
# Out:
#   거래구분 취소유형     단말기번호          발급사  매입사 매입방식                거래일시 체크  \
# 0   승인       12728749   광주           비씨  NaN   18/01/02 20:53:47
# 1   승인       12728749   삼성           삼성  NaN   18/01/02 20:59:42
# 2   승인       12728749   삼성           삼성  NaN   18/01/02 21:00:48
# 3   승인       12728749   신한           신한  NaN   18/01/02 21:06:26
# 4   승인       12728749   농협           농협  NaN   18/01/02 21:37:16
#
#                    카드번호  할부기간      승인번호            금액      봉사료           세금
# 0   4599-52**-****-2072   0.0  71288818   132000(KRW)   0(KRW)   11989(KRW)
# 1   4009-07**-****-7087   0.0  39611435    56000(KRW)   0(KRW)    5084(KRW)
# 2   4009-13**-****-0782   0.0  57213771    42000(KRW)   0(KRW)    3815(KRW)
# 3   5525-76**-****-4376   0.0  32901496    93000(KRW)   0(KRW)    8449(KRW)
# 4   4092-16**-****-5617   0.0  30000702    66000(KRW)   0(KRW)    5995(KRW)

# %%
cash_df["발급사"] = "현금"

# %%
cash_df.head()
# Out:
#   거래유형     거래종류 K/S                  사용자정보       금액  봉사료      세금         승인번호  \
# 0   승인  사업자지출증빙   K          010-****-3337   33,000    0   2,997  122866901.0
# 1   승인  소비자소득공제   K          010-****-8265   18,000    0   1,636  122843518.0
# 2   승인  사업자지출증빙   S  1544-2020-****-972922  108,000    0   9,813  122875332.0
# 3   승인  사업자지출증빙   K           11*-**-*3664  184,000    0  16,720  121137601.0
# 4   승인  사업자지출증빙   K           10*-**-*0667   88,000    0   7,992  121132584.0
#
#            상호       사업자번호     단말기번호        제품번호               거래일시  거절사유 취소유형  \
# 0  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-30 18:19:31  정상완료  NaN
# 1  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-25 23:21:55  정상완료  NaN
# 2  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-15 19:54:36  정상완료  NaN
# 3  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-13 20:11:39  정상완료  NaN
# 4  강너머남촌숯불닭갈비  2364100335  12728749  8070501001  18-03-04 20:42:03  정상완료  NaN
#
#   원거래일시  원거래승인번호 발급사
# ...

# %%
cash_df[["발급사", "금액", "세금", "거래일시"]]
# Out:
#     발급사       금액      세금               거래일시
# 0    현금   33,000   2,997  18-03-30 18:19:31
# 1    현금   18,000   1,636  18-03-25 23:21:55
# 2    현금  108,000   9,813  18-03-15 19:54:36
# 3    현금  184,000  16,720  18-03-13 20:11:39
# 4    현금   88,000   7,992  18-03-04 20:42:03
# ..   ..      ...     ...                ...
# 209  현금   39,000   3,542  20-11-04 22:41:28
# 210  현금   46,000   4,177  20-11-04 20:19:04
# 211  현금   48,000   4,359  20-11-01 21:16:23
# 212  현금   63,000   5,721  20-10-30 19:24:07
# 213  현금  188,000  17,086  20-10-11 18:17:23
#
# [214 rows x 4 columns]

# %%
credit_df[["발급사", "금액", "세금", "거래일시"]]
# Out:
#                발급사            금액           세금                거래일시
# 0       광주           132000(KRW)   11989(KRW)   18/01/02 20:53:47
# 1       삼성            56000(KRW)    5084(KRW)   18/01/02 20:59:42
# 2       삼성            42000(KRW)    3815(KRW)   18/01/02 21:00:48
# 3       신한            93000(KRW)    8449(KRW)   18/01/02 21:06:26
# 4       농협            66000(KRW)    5995(KRW)   18/01/02 21:37:16
# ...            ...           ...          ...                 ...
# 19425           신한        39,000        3,542   20-12-18 20:41:09
# 19426           비씨        78,000        7,090   20-12-18 20:46:41
# 19427           삼성        71,000        6,452   20-12-18 20:58:36
# 19428           현대       155,000       14,079   20-12-18 20:59:03
# 19429           신한       104,000        9,448   20-12-18 21:00:46
#
# [18953 rows x 4 columns]

# %%
credit_df2 = credit_df[["발급사", "금액", "세금", "거래일시"]]
cash_df2 = cash_df[["발급사", "금액", "세금", "거래일시"]]

# %%
total_df = pd.concat([credit_df2, cash_df2])

# %%
total_df
# Out:
#              발급사            금액           세금                거래일시
# 0     광주           132000(KRW)   11989(KRW)   18/01/02 20:53:47
# 1     삼성            56000(KRW)    5084(KRW)   18/01/02 20:59:42
# 2     삼성            42000(KRW)    3815(KRW)   18/01/02 21:00:48
# 3     신한            93000(KRW)    8449(KRW)   18/01/02 21:06:26
# 4     농협            66000(KRW)    5995(KRW)   18/01/02 21:37:16
# ..           ...           ...          ...                 ...
# 209           현금        39,000        3,542   20-11-04 22:41:28
# 210           현금        46,000        4,177   20-11-04 20:19:04
# 211           현금        48,000        4,359   20-11-01 21:16:23
# 212           현금        63,000        5,721   20-10-30 19:24:07
# 213           현금       188,000       17,086   20-10-11 18:17:23
#
# [19167 rows x 4 columns]

# %%
total_df.거래일시 = total_df.거래일시.str.replace("/", "-")

# %%
total_df
# Out:
#              발급사            금액           세금                거래일시
# 0     광주           132000(KRW)   11989(KRW)   18-01-02 20:53:47
# 1     삼성            56000(KRW)    5084(KRW)   18-01-02 20:59:42
# 2     삼성            42000(KRW)    3815(KRW)   18-01-02 21:00:48
# 3     신한            93000(KRW)    8449(KRW)   18-01-02 21:06:26
# 4     농협            66000(KRW)    5995(KRW)   18-01-02 21:37:16
# ..           ...           ...          ...                 ...
# 209           현금        39,000        3,542   20-11-04 22:41:28
# 210           현금        46,000        4,177   20-11-04 20:19:04
# 211           현금        48,000        4,359   20-11-01 21:16:23
# 212           현금        63,000        5,721   20-10-30 19:24:07
# 213           현금       188,000       17,086   20-10-11 18:17:23
#
# [19167 rows x 4 columns]

# %%
import datetime

# %%
total_df["거래일시2"] = '20' + total_df["거래일시"]

# %%
total_df["거래일시2"] = total_df["거래일시2"].str.replace("20 18-", "2018-")
total_df["거래일시2"] = total_df["거래일시2"].str.replace("20 19-", "2019-")
total_df["거래일시2"] = total_df["거래일시2"].str.replace("20 20-", "2020-")

# %%
total_df["거래일시2"]
# Out:
# 0      2018-01-02 20:53:47
# 1      2018-01-02 20:59:42
# 2      2018-01-02 21:00:48
# 3      2018-01-02 21:06:26
# 4      2018-01-02 21:37:16
#               ...
# 209    2020-11-04 22:41:28
# 210    2020-11-04 20:19:04
# 211    2020-11-01 21:16:23
# 212    2020-10-30 19:24:07
# 213    2020-10-11 18:17:23
# Name: 거래일시2, Length: 19167, dtype: object

# %%
total_df["거래일시3"] = pd.to_datetime(total_df["거래일시2"], format = '%Y-%m-%d %H:%M:%S')

# %%
total_df["거래일시3"].head()
# Out:
# 0   2018-01-02 20:53:47
# 1   2018-01-02 20:59:42
# 2   2018-01-02 21:00:48
# 3   2018-01-02 21:06:26
# 4   2018-01-02 21:37:16
# Name: 거래일시3, dtype: datetime64[ns]

# %%
total_df["거래일"] = pd.to_datetime(total_df["거래일시2"], format = '%Y-%m-%d')

# %%
total_df["거래시간"] = pd.to_datetime(total_df["거래일시3"], format = '%H:%M:%S')

# %%
total_df.head()
# Out:
#            발급사            금액           세금                거래일시  \
# 0   광주           132000(KRW)   11989(KRW)   18-01-02 20:53:47
# 1   삼성            56000(KRW)    5084(KRW)   18-01-02 20:59:42
# 2   삼성            42000(KRW)    3815(KRW)   18-01-02 21:00:48
# 3   신한            93000(KRW)    8449(KRW)   18-01-02 21:06:26
# 4   농협            66000(KRW)    5995(KRW)   18-01-02 21:37:16
#
#                  거래일시2               거래일시3                 거래일  \
# 0  2018-01-02 20:53:47 2018-01-02 20:53:47 2018-01-02 20:53:47
# 1  2018-01-02 20:59:42 2018-01-02 20:59:42 2018-01-02 20:59:42
# 2  2018-01-02 21:00:48 2018-01-02 21:00:48 2018-01-02 21:00:48
# 3  2018-01-02 21:06:26 2018-01-02 21:06:26 2018-01-02 21:06:26
# 4  2018-01-02 21:37:16 2018-01-02 21:37:16 2018-01-02 21:37:16
#
#                  거래시간
# 0 2018-01-02 20:53:47
# 1 2018-01-02 20:59:42
# 2 2018-01-02 21:00:48
# 3 2018-01-02 21:06:26
# 4 2018-01-02 21:37:16

# %%
total_df.reset_index(drop=True, inplace=True)

# %%
for i in range(0, len(total_df)):
    total_df["거래일"][i] = total_df["거래일시3"][i].date()
# Out:
# <ipython-input-64-69b8cc01437a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래일"][i] = total_df["거래일시3"][i].date()

# %%
for i in range(0, len(total_df)):
    total_df["거래시간"][i] = total_df["거래일시3"][i].time()
# Out:
# <ipython-input-65-767f68f8fd80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래시간"][i] = total_df["거래일시3"][i].time()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
from datetime import datetime

# %%
from datetime import time

# %%
total_df["거래일시3"][1].strftime("%H")
# Out:
# '20'

# %%
total_df["거래시간2"] =total_df["거래시간"]

# %%
for i in range(0, len(total_df)):
    total_df["거래시간2"][i] = total_df["거래일시3"][i].strftime("%H")
# Out:
# <ipython-input-70-acd02ce5db0a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래시간2"][i] = total_df["거래일시3"][i].strftime("%H")

# %%
total_df["거래일2"] =total_df["거래일"]

# %%
for i in range(0, len(total_df)):
    total_df["거래일2"][i] = total_df["거래일시3"][i].strftime("%Y-%m")
# Out:
# <ipython-input-72-91e360cb83b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래일2"][i] = total_df["거래일시3"][i].strftime("%Y-%m")

# %%
total_df["거래일3"] =total_df["거래일"]
for i in range(0, len(total_df)):
    total_df["거래일3"][i] = total_df["거래일시3"][i].strftime("%Y")
# Out:
# <ipython-input-73-0ef339835ca0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래일3"][i] = total_df["거래일시3"][i].strftime("%Y")

# %%
total_df["결제건수"] = 1

# %%
total_df.head()
# Out:
#            발급사            금액           세금                거래일시  \
# 0   광주           132000(KRW)   11989(KRW)   18-01-02 20:53:47
# 1   삼성            56000(KRW)    5084(KRW)   18-01-02 20:59:42
# 2   삼성            42000(KRW)    3815(KRW)   18-01-02 21:00:48
# 3   신한            93000(KRW)    8449(KRW)   18-01-02 21:06:26
# 4   농협            66000(KRW)    5995(KRW)   18-01-02 21:37:16
#
#                  거래일시2               거래일시3        거래일      거래시간 거래시간2  \
# 0  2018-01-02 20:53:47 2018-01-02 20:53:47 2018-01-02  20:53:47    20
# 1  2018-01-02 20:59:42 2018-01-02 20:59:42 2018-01-02  20:59:42    20
# 2  2018-01-02 21:00:48 2018-01-02 21:00:48 2018-01-02  21:00:48    21
# 3  2018-01-02 21:06:26 2018-01-02 21:06:26 2018-01-02  21:06:26    21
# 4  2018-01-02 21:37:16 2018-01-02 21:37:16 2018-01-02  21:37:16    21
#
#       거래일2  거래일3  결제건수
# 0  2018-01  2018     1
# 1  2018-01  2018     1
# 2  2018-01  2018     1
# 3  2018-01  2018     1
# 4  2018-01  2018     1

# %%
total_df.발급사 = total_df.발급사.str.replace(" ", "")
total_df.발급사 = total_df.발급사.str.replace("시티", "CITI")
total_df.금액 = total_df.금액.str.replace("(KRW)", "")
total_df.금액 = total_df.금액.str.replace("(", "")
total_df.금액 = total_df.금액.str.replace(")", "")
total_df.세금 = total_df.세금.str.replace("(KRW)", "")
total_df.세금 = total_df.세금.str.replace("(", "")
total_df.세금 = total_df.세금.str.replace(")", "")

# %%
total_df.발급사.value_counts()
# Out:
# 비씨      4824
# 신한      4155
# KB국민    3052
# 현대      1537
# 삼성      1379
# 하나      1152
# 농협      1111
# 외환       642
# 롯데       623
# 현금       214
# CITI     157
# 신협       110
# 해외        96
# 신세계       34
# 전북        33
# 수협        29
# 광주        14
# 제주         5
# Name: 발급사, dtype: int64

# %%
day = ["1.월요일","2.화요일","3.수요일","4.목요일","5.금요일","6.토요일","7.일요일"]

# %%
day[total_df["거래일"][1].weekday()]
# Out:
# '2.화요일'

# %%
 total_df["요일"] = "요일"

# %%
for i in range(0, len(total_df)):
    total_df["요일"][i] = day[total_df["거래일"][i].weekday()]
# Out:
# <ipython-input-81-f498a7f987b5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["요일"][i] = day[total_df["거래일"][i].weekday()]

# %%
total_df["거래일4"] =total_df["거래일"]
for i in range(0, len(total_df)):
    total_df["거래일4"][i] = total_df["거래일시3"][i].strftime("%m")
# Out:
# <ipython-input-82-1a61f6975bc3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래일4"][i] = total_df["거래일시3"][i].strftime("%m")
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
total_df["거래일5"] =total_df["거래일"]
for i in range(0, len(total_df)):
    total_df["거래일5"][i] = total_df["거래일시3"][i].strftime("%m%d")
# Out:
# <ipython-input-83-3324e2c35cb6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["거래일5"][i] = total_df["거래일시3"][i].strftime("%m%d")

# %%
total_df.head()
# Out:
#   발급사       금액      세금                거래일시                거래일시2  \
# 0  광주   132000   11989   18-01-02 20:53:47  2018-01-02 20:53:47
# 1  삼성    56000    5084   18-01-02 20:59:42  2018-01-02 20:59:42
# 2  삼성    42000    3815   18-01-02 21:00:48  2018-01-02 21:00:48
# 3  신한    93000    8449   18-01-02 21:06:26  2018-01-02 21:06:26
# 4  농협    66000    5995   18-01-02 21:37:16  2018-01-02 21:37:16
#
#                 거래일시3        거래일      거래시간 거래시간2     거래일2  거래일3  결제건수     요일  \
# 0 2018-01-02 20:53:47 2018-01-02  20:53:47    20  2018-01  2018     1  2.화요일
# 1 2018-01-02 20:59:42 2018-01-02  20:59:42    20  2018-01  2018     1  2.화요일
# 2 2018-01-02 21:00:48 2018-01-02  21:00:48    21  2018-01  2018     1  2.화요일
# 3 2018-01-02 21:06:26 2018-01-02  21:06:26    21  2018-01  2018     1  2.화요일
# 4 2018-01-02 21:37:16 2018-01-02  21:37:16    21  2018-01  2018     1  2.화요일
#
#   거래일4  거래일5
# 0   01  0102
# 1   01  0102
# 2   01  0102
# 3   01  0102
# 4   01  0102

# %%
table_date_cnt = total_df.groupby(["거래일3", "요일"], as_index=False)["결제건수"].sum()

# %%
table_date_cnt
# Out:
#     거래일3     요일  결제건수
# 0   2018  1.월요일   809
# 1   2018  2.화요일   982
# 2   2018  3.수요일   890
# 3   2018  4.목요일   961
# 4   2018  5.금요일  1082
# 5   2018  6.토요일   804
# 6   2018  7.일요일   677
# 7   2019  1.월요일   960
# 8   2019  2.화요일  1088
# 9   2019  3.수요일  1093
# 10  2019  4.목요일  1156
# 11  2019  5.금요일  1263
# 12  2019  6.토요일  1076
# 13  2019  7.일요일   947
# 14  2020  1.월요일   765
# 15  2020  2.화요일   877
# 16  2020  3.수요일   871
# 17  2020  4.목요일   898
# 18  2020  5.금요일   990
# 19  2020  6.토요일   504
# 20  2020  7.일요일   474

# %%
total_df.금액 =total_df.금액.str.replace(",","")

# %%
total_df.금액 = total_df.금액.astype(int)

# %%
table_date_amt = total_df.groupby(["거래일3", "요일"], as_index=False)["금액"].sum()

# %%
table_date_cnt.pivot("요일", "거래일3", "결제건수")
# Out:
# 거래일3   2018  2019  2020
# 요일
# 1.월요일   809   960   765
# 2.화요일   982  1088   877
# 3.수요일   890  1093   871
# 4.목요일   961  1156   898
# 5.금요일  1082  1263   990
# 6.토요일   804  1076   504
# 7.일요일   677   947   474

# %%
table_date_amt.pivot("요일", "거래일3", "금액")
# Out:
# 거래일3       2018      2019      2020
# 요일
# 1.월요일  61958000  68877000  58059000
# 2.화요일  73133000  83084000  68788600
# 3.수요일  65540000  81926500  65568000
# 4.목요일  74899000  86607000  71808000
# 5.금요일  73851000  88543500  71641000
# 6.토요일  50288000  67308000  33176500
# 7.일요일  38896000  53522800  31187000

# %%
table_date_cnt_amt = pd.merge(table_date_cnt, table_date_amt, on=["거래일3","요일"], how='left')

# %%
table_date_cnt_amt['건당결제금액'] = table_date_cnt_amt.금액 / table_date_cnt_amt.결제건수

# %%
table_date_cnt_amt['건당결제금액'] = table_date_cnt_amt['건당결제금액'].astype(int)

# %%
table_date_cnt_amt.pivot("요일", "거래일3", "건당결제금액")
# Out:
# 거래일3    2018   2019   2020
# 요일
# 1.월요일  76585  71746  75894
# 2.화요일  74473  76363  78436
# 3.수요일  73640  74955  75278
# 4.목요일  77938  74919  79964
# 5.금요일  68254  70105  72364
# 6.토요일  62547  62553  65826
# 7.일요일  57453  56518  65795

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc('font', family='NanumGothic')
plt.rcParams["figure.figsize"] = (12,9)

# %%
sns.lineplot(x='요일', y="결제건수", hue = '거래일3',data=table_date_cnt)

# %%
sns.lineplot(x='요일', y="금액", hue = '거래일3',data=table_date_amt)

# %%
table_2 = total_df.groupby(["거래일4","거래일3" ], as_index=False)[["결제건수", "금액"]].sum()

# %%
table_2.head()
# Out:
#   거래일4  거래일3  결제건수        금액
# 0   01  2018   418  32273000
# 1   01  2019   580  43810000
# 2   01  2020   520  38698000
# 3   02  2018   393  27141000
# 4   02  2019   524  38390000

# %%
sns.lineplot(x='거래일4', y="결제건수", hue = '거래일3',data=table_2)

# %%
sns.lineplot(x='거래일4', y="금액", hue = '거래일3',data=table_2)

# %%
total_df.head()
# Out:
#   발급사      금액      세금                거래일시                거래일시2  \
# 0  광주  132000   11989   18-01-02 20:53:47  2018-01-02 20:53:47
# 1  삼성   56000    5084   18-01-02 20:59:42  2018-01-02 20:59:42
# 2  삼성   42000    3815   18-01-02 21:00:48  2018-01-02 21:00:48
# 3  신한   93000    8449   18-01-02 21:06:26  2018-01-02 21:06:26
# 4  농협   66000    5995   18-01-02 21:37:16  2018-01-02 21:37:16
#
#                 거래일시3        거래일      거래시간 거래시간2     거래일2  거래일3  결제건수     요일  \
# 0 2018-01-02 20:53:47 2018-01-02  20:53:47    20  2018-01  2018     1  2.화요일
# 1 2018-01-02 20:59:42 2018-01-02  20:59:42    20  2018-01  2018     1  2.화요일
# 2 2018-01-02 21:00:48 2018-01-02  21:00:48    21  2018-01  2018     1  2.화요일
# 3 2018-01-02 21:06:26 2018-01-02  21:06:26    21  2018-01  2018     1  2.화요일
# 4 2018-01-02 21:37:16 2018-01-02  21:37:16    21  2018-01  2018     1  2.화요일
#
#   거래일4  거래일5
# 0   01  0102
# 1   01  0102
# 2   01  0102
# 3   01  0102
# 4   01  0102

# %%
table_3 = total_df.groupby(["거래시간2","거래일3","요일" ], as_index=False)[["결제건수", "금액"]].sum()

# %%
sns.lineplot(x='거래시간2', y="금액", hue = '거래일3',data=table_3, ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = '거래일3',data=table_3, ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = '거래일3',data=table_3[table_3.요일=='1.월요일'], ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = '거래일3',data=table_3[table_3.요일=='2.화요일'], ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = '거래일3',data=table_3[table_3.요일=='5.금요일'], ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = "요일",data=table_3, ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = "요일",data=table_3[table_3.거래일3=="2018"], ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = "요일",data=table_3[table_3.거래일3=="2019"], ci=None)

# %%
sns.lineplot(x='거래시간2', y="결제건수", hue = "요일",data=table_3[table_3.거래일3=="2020"], ci=None)

# %%
total_df.head()
# Out:
#   발급사      금액      세금                거래일시                거래일시2  \
# 0  광주  132000   11989   18-01-02 20:53:47  2018-01-02 20:53:47
# 1  삼성   56000    5084   18-01-02 20:59:42  2018-01-02 20:59:42
# 2  삼성   42000    3815   18-01-02 21:00:48  2018-01-02 21:00:48
# 3  신한   93000    8449   18-01-02 21:06:26  2018-01-02 21:06:26
# 4  농협   66000    5995   18-01-02 21:37:16  2018-01-02 21:37:16
#
#                 거래일시3        거래일      거래시간 거래시간2     거래일2  거래일3  결제건수     요일  \
# 0 2018-01-02 20:53:47 2018-01-02  20:53:47    20  2018-01  2018     1  2.화요일
# 1 2018-01-02 20:59:42 2018-01-02  20:59:42    20  2018-01  2018     1  2.화요일
# 2 2018-01-02 21:00:48 2018-01-02  21:00:48    21  2018-01  2018     1  2.화요일
# 3 2018-01-02 21:06:26 2018-01-02  21:06:26    21  2018-01  2018     1  2.화요일
# 4 2018-01-02 21:37:16 2018-01-02  21:37:16    21  2018-01  2018     1  2.화요일
#
#   거래일4  거래일5
# 0   01  0102
# 1   01  0102
# 2   01  0102
# 3   01  0102
# 4   01  0102

# %%
table_4 = total_df.groupby(["발급사", "거래일3", "거래일4"], as_index=False)["결제건수","금액"].sum()
# Out:
# <ipython-input-123-4a47f59d9572>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   table_4 = total_df.groupby(["발급사", "거래일3", "거래일4"], as_index=False)["결제건수","금액"].sum()

# %%
table_4.head()
# Out:
#     발급사  거래일3 거래일4  결제건수      금액
# 0  CITI  2018   01     2   70000
# 1  CITI  2018   02     5  346000
# 2  CITI  2018   03     3  274000
# 3  CITI  2018   04     2   99000
# 4  CITI  2018   05    12  731000

# %%
sns.lineplot(x='거래일4', y="결제건수", hue = "거래일3",data=table_4[(table_4.발급사=="KB국민")|(table_4.발급사=="비씨")|(table_4.발급사=="신한")], ci=None)

# %%
sns.lineplot(x='거래일4', y="결제건수", hue = "거래일3",data=table_4[(table_4.발급사=="KB국민")], ci=None)

# %%
sns.lineplot(x='거래일4', y="결제건수", hue = "거래일3",data=table_4[(table_4.발급사=="비씨")], ci=None)

# %%
sns.lineplot(x='거래일4', y="결제건수", hue = "거래일3",data=table_4[(table_4.발급사=="신한")], ci=None)

# %%
table_4
# Out:
#       발급사  거래일3 거래일4  결제건수       금액
# 0    CITI  2018   01     2    70000
# 1    CITI  2018   02     5   346000
# 2    CITI  2018   03     3   274000
# 3    CITI  2018   04     2    99000
# 4    CITI  2018   05    12   731000
# ..    ...   ...  ...   ...      ...
# 527    현대  2020   08    36  2245000
# 528    현대  2020   09    34  2764000
# 529    현대  2020   10    35  2940000
# 530    현대  2020   11    33  2505000
# 531    현대  2020   12    15  1057000
#
# [532 rows x 5 columns]

# %%
import copy

# %%
df_for_estimation = copy.deepcopy(total_df)

# %%
df_for_estimation = df_for_estimation[["발급사", "금액","결제건수", "거래일", "거래일3", "거래일4", "거래일5", "요일"]]

# %%
df_for_estimation.head()
# Out:
#   발급사      금액  결제건수        거래일  거래일3 거래일4  거래일5     요일
# 0  광주  132000     1 2018-01-02  2018   01  0102  2.화요일
# 1  삼성   56000     1 2018-01-02  2018   01  0102  2.화요일
# 2  삼성   42000     1 2018-01-02  2018   01  0102  2.화요일
# 3  신한   93000     1 2018-01-02  2018   01  0102  2.화요일
# 4  농협   66000     1 2018-01-02  2018   01  0102  2.화요일

# %%
df_for_estimation2 = df_for_estimation.groupby(["거래일","거래일3","거래일4","거래일5","요일"], as_index=False)["금액","결제건수"].sum()
# Out:
# <ipython-input-134-5f6a552a8461>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_for_estimation2 = df_for_estimation.groupby(["거래일","거래일3","거래일4","거래일5","요일"], as_index=False)["금액","결제건수"].sum()

# %%
df_for_estimation2.결제건수.mean()
# Out:
# 18.644941634241246

# %%
df_for_estimation2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 0 to 1027
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래일     1028 non-null   datetime64[ns]
#  1   거래일3    1028 non-null   object
#  2   거래일4    1028 non-null   object
#  3   거래일5    1028 non-null   object
#  4   요일      1028 non-null   object
#  5   금액      1028 non-null   int32
#  6   결제건수    1028 non-null   int64
# dtypes: datetime64[ns](1), int32(1), int64(1), object(4)
# memory usage: 60.2+ KB

# %%
df_for_estimation2[df_for_estimation2.거래일 <'2018-03-31']
# Out:
#           거래일  거래일3 거래일4  거래일5     요일       금액  결제건수
# 0  2018-01-02  2018   01  0102  2.화요일  1212000    13
# 1  2018-01-03  2018   01  0103  3.수요일   990000    17
# 2  2018-01-04  2018   01  0104  4.목요일  1316000    17
# 3  2018-01-05  2018   01  0105  5.금요일   991000    18
# 4  2018-01-06  2018   01  0106  6.토요일   954000    13
# ..        ...   ...  ...   ...    ...      ...   ...
# 83 2018-03-26  2018   03  0326  1.월요일   780000    14
# 84 2018-03-27  2018   03  0327  2.화요일  1217000    14
# 85 2018-03-28  2018   03  0328  3.수요일  1622000    24
# 86 2018-03-29  2018   03  0329  4.목요일  1894000    23
# 87 2018-03-30  2018   03  0330  5.금요일  1299000    23
#
# [88 rows x 7 columns]

# %%
df_for_estimation2['건당결제금액'] = df_for_estimation2.금액 / df_for_estimation2.결제건수

# %%
sns.lineplot(x='거래일', y='건당결제금액', data=df_for_estimation2)

# %%
df_for_estimation2['건당결제금액'].max()
# Out:
# 653250.0

# %%
df_for_estimation2[df_for_estimation2['건당결제금액'] == df_for_estimation2['건당결제금액'].max() ]
# Out:
#           거래일  거래일3 거래일4  거래일5     요일       금액  결제건수    건당결제금액
# 27 2018-01-29  2018   01  0129  1.월요일  2613000     4  653250.0

# %%
df_for_estimation2[df_for_estimation2['건당결제금액'] == df_for_estimation2['건당결제금액'].min() ]
# Out:
#           거래일  거래일3 거래일4  거래일5     요일      금액  결제건수        건당결제금액
# 54 2018-02-25  2018   02  0225  7.일요일  413000    13  31769.230769

# %%
df_for_estimation2[26:29]
# Out:
#           거래일  거래일3 거래일4  거래일5     요일       금액  결제건수         건당결제금액
# 26 2018-01-28  2018   01  0128  7.일요일   318000     6   53000.000000
# 27 2018-01-29  2018   01  0129  1.월요일  2613000     4  653250.000000
# 28 2018-01-30  2018   01  0130  2.화요일  2008000    21   95619.047619

# %%
df_for_estimation2['방문인원수예측'] = df_for_estimation2.금액 / 25000

# %%
plt.subplots(figsize=(40, 5))
sns.lineplot(x='거래일', y='방문인원수예측', data=df_for_estimation2[df_for_estimation2.거래일 <= '2018-02-28'])

# %%
plt.subplots(figsize=(40, 5))
sns.lineplot(x='거래일', y='결제건수', data=df_for_estimation2[df_for_estimation2.거래일 <= '2018-02-28'])

# %%
df_for_estimation2["거래년월"] = df_for_estimation2.거래일3 +'-'+ df_for_estimation2.거래일4

# %%
df_for_estimation3 = df_for_estimation2.groupby(["거래년월"], as_index=False)['금액','결제건수','방문인원수예측'].sum()
# Out:
# <ipython-input-148-50c8f8a9b8f9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_for_estimation3 = df_for_estimation2.groupby(["거래년월"], as_index=False)['금액','결제건수','방문인원수예측'].sum()

# %%
plt.subplots(figsize=(40, 5))
sns.lineplot(x='거래년월', y='방문인원수예측', data=df_for_estimation3)

# %%
plt.subplots(figsize=(40, 5))
sns.barplot(x='거래년월', y='금액', data=df_for_estimation3, color='grey')

# %%
plt.subplots(figsize=(40, 5))
sns.lineplot(x='거래년월', y='결제건수', data=df_for_estimation3)

# %%
df_for_estimation3["건당결제금액"] = df_for_estimation3["금액"] /df_for_estimation3["결제건수"]

# %%
plt.subplots(figsize=(40, 5))
sns.barplot(x='거래년월', y='건당결제금액', data=df_for_estimation3, color='skyblue')

# %%
df_for_estimation3.head()
# Out:
#       거래년월        금액  결제건수  방문인원수예측        건당결제금액
# 0  2018-01  32273000   418  1290.92  77208.133971
# 1  2018-02  27141000   393  1085.64  69061.068702
# 2  2018-03  37227000   506  1489.08  73571.146245
# 3  2018-04  39040000   500  1561.60  78080.000000
# 4  2018-05  40578000   568  1623.12  71440.140845

# %%
card_brand_df = df_for_estimation.groupby(["발급사","거래일3",'거래일4'], as_index=False)["금액","결제건수"].sum()
# Out:
# <ipython-input-155-634593ca69d1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   card_brand_df = df_for_estimation.groupby(["발급사","거래일3",'거래일4'], as_index=False)["금액","결제건수"].sum()

# %%
card_brand_df2 = card_brand_df.groupby(['발급사','거래일3'], as_index=False)["금액","결제건수"].sum()
# Out:
# <ipython-input-156-1eb6cdce44da>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   card_brand_df2 = card_brand_df.groupby(['발급사','거래일3'], as_index=False)["금액","결제건수"].sum()

# %%
plt.subplots(figsize=(40, 5))
sns.barplot(x='발급사', y='금액',hue='거래일3', data=card_brand_df2, color='grey')

# %%
plt.subplots(figsize=(40, 5))
sns.barplot(x='발급사', y='결제건수',hue='거래일3', data=card_brand_df2, color='grey')

# %%
df_for_estimation2.head()
# Out:
#          거래일  거래일3 거래일4  거래일5     요일       금액  결제건수        건당결제금액  방문인원수예측  \
# 0 2018-01-02  2018   01  0102  2.화요일  1212000    13  93230.769231    48.48
# 1 2018-01-03  2018   01  0103  3.수요일   990000    17  58235.294118    39.60
# 2 2018-01-04  2018   01  0104  4.목요일  1316000    17  77411.764706    52.64
# 3 2018-01-05  2018   01  0105  5.금요일   991000    18  55055.555556    39.64
# 4 2018-01-06  2018   01  0106  6.토요일   954000    13  73384.615385    38.16
#
#       거래년월
# 0  2018-01
# 1  2018-01
# 2  2018-01
# 3  2018-01
# 4  2018-01

# %%
df_for_estimation2.tail()
# Out:
#             거래일  거래일3 거래일4  거래일5     요일       금액  결제건수        건당결제금액  방문인원수예측  \
# 1023 2020-12-11  2020   12  1211  5.금요일   688000    11  62545.454545    27.52
# 1024 2020-12-14  2020   12  1214  1.월요일   305000     6  50833.333333    12.20
# 1025 2020-12-16  2020   12  1216  3.수요일   968000    12  80666.666667    38.72
# 1026 2020-12-17  2020   12  1217  4.목요일   286000     5  57200.000000    11.44
# 1027 2020-12-18  2020   12  1218  5.금요일  1024000    11  93090.909091    40.96
#
#          거래년월
# 1023  2020-12
# 1024  2020-12
# 1025  2020-12
# 1026  2020-12
# 1027  2020-12

# %%
test_df = copy.deepcopy(df_for_estimation2[(df_for_estimation2.거래일 >='2018-03-01') & (df_for_estimation2.거래일 <='2018-10-31')])

# %%
test_df.reset_index(drop=True, inplace=True)

# %%
test_df.거래일 = test_df.거래일.astype(str)

# %%
test_df
# Out:
#             거래일  거래일3 거래일4  거래일5     요일       금액  결제건수         건당결제금액  \
# 0    2018-03-01  2018   03  0301  4.목요일   742000    13   57076.923077
# 1    2018-03-02  2018   03  0302  5.금요일  1000000    20   50000.000000
# 2    2018-03-03  2018   03  0303  6.토요일   685000    15   45666.666667
# 3    2018-03-04  2018   03  0304  7.일요일   704000    14   50285.714286
# 4    2018-03-05  2018   03  0305  1.월요일  1289000    12  107416.666667
# ..          ...   ...  ...   ...    ...      ...   ...            ...
# 239  2018-10-27  2018   10  1027  6.토요일   996000    18   55333.333333
# 240  2018-10-28  2018   10  1028  7.일요일  1249000    19   65736.842105
# 241  2018-10-29  2018   10  1029  1.월요일  1444000    21   68761.904762
# 242  2018-10-30  2018   10  1030  2.화요일  1192000    15   79466.666667
# 243  2018-10-31  2018   10  1031  3.수요일  1574000    18   87444.444444
#
#      방문인원수예측     거래년월
# 0      29.68  2018-03
# 1      40.00  2018-03
# 2      27.40  2018-03
# 3      28.16  2018-03
# ...

# %%
X = test_df[["거래일3","거래일5","요일"]]
y = test_df["결제건수"]

# %%
y = y.values

# %%
day_dic = {"1.월요일":"월요일", "2.화요일":"화요일","3.수요일":"수요일", "4.목요일":"목요일","5.금요일":"금요일","6.토요일":"토요일","7.일요일":"일요일"}

# %%
X.요일 = X.요일.map(day_dic)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
X[X.요일.isnull()]
# Out:
# Empty DataFrame
# Columns: [거래일3, 거래일5, 요일]
# Index: []

# %%
enc = OneHotEncoder()
enc.fit(X)
# Out:
# OneHotEncoder()

# %%
X.head()
# Out:
#    거래일3  거래일5   요일
# 0  2018  0301  목요일
# 1  2018  0302  금요일
# 2  2018  0303  토요일
# 3  2018  0304  일요일
# 4  2018  0305  월요일

# %%
X.tail()
# Out:
#      거래일3  거래일5   요일
# 239  2018  1027  토요일
# 240  2018  1028  일요일
# 241  2018  1029  월요일
# 242  2018  1030  화요일
# 243  2018  1031  수요일

# %%
X[X.요일=='월요일']
# Out:
#      거래일3  거래일5   요일
# 4    2018  0305  월요일
# 11   2018  0312  월요일
# 18   2018  0319  월요일
# 25   2018  0326  월요일
# 32   2018  0402  월요일
# 39   2018  0409  월요일
# 46   2018  0416  월요일
# 53   2018  0423  월요일
# 60   2018  0430  월요일
# 67   2018  0507  월요일
# 74   2018  0514  월요일
# 81   2018  0521  월요일
# 88   2018  0528  월요일
# 95   2018  0604  월요일
# 102  2018  0611  월요일
# 109  2018  0618  월요일
# 116  2018  0625  월요일
# 123  2018  0702  월요일
# 130  2018  0709  월요일
# 137  2018  0716  월요일
# 144  2018  0723  월요일
# 151  2018  0730  월요일
# 158  2018  0806  월요일
# 165  2018  0813  월요일
# 172  2018  0820  월요일
# 179  2018  0827  월요일
# 186  2018  0903  월요일
# 193  2018  0910  월요일
# 200  2018  0917  월요일
# 213  2018  1001  월요일
# 220  2018  1008  월요일
# 227  2018  1015  월요일
# 234  2018  1022  월요일
# 241  2018  1029  월요일

# %%
X1 = X[X.요일=='월요일']

# %%
X1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 4 to 241
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래일3    34 non-null     object
#  1   거래일5    34 non-null     object
#  2   요일      34 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
X_onehot = enc.transform(X).toarray()

# %%
X_onehot = pd.DataFrame(X_onehot)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
standardScaler = StandardScaler()
minmaxScaler= MinMaxScaler()

# %%
y = np.array(pd.DataFrame(y))

# %%
minmaxScaler = MinMaxScaler(feature_range=(0,1))
y_minmaxScaled = minmaxScaler.fit_transform(y)

# %%
standardScaler = StandardScaler()
y_standardScaled = standardScaler.fit_transform(y)

# %%
pd.DataFrame(y_standardScaled)
# Out:
#             0
# 0   -0.856315
# 1    0.405623
# 2   -0.495761
# 3   -0.676038
# 4   -1.036592
# ..        ...
# 239  0.045069
# 240  0.225346
# 241  0.585900
# 242 -0.495761
# 243  0.045069
#
# [244 rows x 1 columns]

# %%
# train 사이즈를 전체 데이터 길이의 80프로로 할 경우 몇번째 index까지 나누어야 하는지 계산 
# 시계열 데이터이므로 train_test_split 쓰면 안됨. 랜덤으로 섞어서 나누어줌. 

round(len(test_df)*.8)
# Out:
# 195

# %%
round(len(X_onehot)*.8)
# Out:
# 195

# %%
X_train = X_onehot[:195] 
X_test = X_onehot[195:] 
y_train = pd.DataFrame(y[:195])
y_test = pd.DataFrame(y[195:] )

# %%
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.metrics import make_scorer

# %%
def rmsle(predicted_values, actual_values):
    # 넘파이로 배열 형태로 바꿔준다.
    predicted_values = np.array(predicted_values)
    actual_values = np.array(actual_values)

    # 예측값과 실제 값에 1을 더하고 로그를 씌워준다.
    log_predict = np.log(predicted_values + 1)
    log_actual = np.log(actual_values + 1)

    # 위에서 계산한 예측값에서 실제값을 빼주고 제곱을 해준다.
    difference = log_predict - log_actual
    # difference = (log_predict - log_actual) ** 2
    difference = np.square(difference)

    # 평균을 낸다.
    mean_difference = difference.mean()

    # 다시 루트를 씌운다.
    score = np.sqrt(mean_difference)

    return score

# %%
rmsle_scorer = make_scorer(rmsle)

# %%
model = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=0)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=0)

# %%
X_test_predict=pd.DataFrame(model.predict(X_test))

# %%
y_test
# Out:
#      0
# 0   18
# 1   14
# 2   24
# 3   13
# 4   15
# 5   11
# 6   24
# 7   25
# 8   31
# 9   22
# 10  13
# 11   1
# 12  19
# 13  10
# 14  18
# 15  19
# 16  17
# 17  19
# 18  26
# 19  26
# 20  14
# 21   8
# 22  22
# 23  37
# 24  10
# 25  16
# 26  26
# 27  16
# 28  18
# 29  23
# 30  22
# 31  19
# 32  12
# 33  17
# 34  26
# 35  20
# 36  19
# 37  24
# 38  17
# 39  15
# 40  21
# 41  27
# 42  16
# 43  26
# 44  18
# 45  19
# 46  21
# 47  15
# 48  18

# %%
X_test_predict.colums = '1'
y_test.rename(columns={0:1},inplace=True)

# %%
X_test_predict.head()
# Out:
#         0
# 0  16.754
# 1  20.780
# 2  22.498
# 3  15.694
# 4  10.796

# %%
y_test.head()
# Out:
#     1
# 0  18
# 1  14
# 2  24
# 3  13
# 4  15

# %%
date = X[195:]

# %%
date.reset_index(drop=True, inplace=True)

# %%
result = X_test_predict.join(y_test).join(date)

# %%
result.head()
# Out:
#         0   1  거래일3  거래일5   요일
# 0  16.754  18  2018  0912  수요일
# 1  20.780  14  2018  0913  목요일
# 2  22.498  24  2018  0914  금요일
# 3  15.694  13  2018  0915  토요일
# 4  10.796  15  2018  0916  일요일

# %%
sns.lineplot(x='거래일5', y=0, data=result)

# %%
sns.lineplot(x='거래일5', y=1, data=result)
